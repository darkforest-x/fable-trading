# %% [markdown]
# ## tl;dr
#
# Saved accounting checks passed for all63 cases/108 controls and36 fixed triples; no profitability certification.

# %% [markdown]
# ## Context & Methods
#
# ### Key Assumptions
# 63 cases /108 controls /36 fixed triples;20bp original-notional costs. Sequential Python exec, not a Jupyter kernel. No raw/MA/inference/serial replay.

# %%
from yoyo.evaluation.owner_k1k2_delayed_entry_report import guard
commit, summary, review, hashes = guard()
print('Saved byte/source and accounting checks passed')
# Out:
# Saved byte/source and accounting checks passed

# %% [markdown]
# ## Data
#
# Only V39 summary and its exact saved CSVs; no archive access.

# %%
import json
print(json.dumps(review['support'], sort_keys=True))
# Out:
# {"cases": 63, "controls": 108, "matched_cases": 36, "unmatched_cases": 27}

# %% [markdown]
# ## Results
#
# Request contributions retain no-fill zero and unknown NaN; completed-trade metrics are separate.

# %%
print(json.dumps(review['metrics'], ensure_ascii=False, sort_keys=True))
# Out:
# {"delayed": {"case": {"executed_closed": 38, "known": 63, "known_no_fill": 25, "mean_known_request_net_bp": -5.764857498339354, "mean_request_gross_bp": 6.298634565152713, "mean_request_net_bp": -5.764857498339354, "mean_trade_net_bp": -9.557526905141563, "median_trade_net_bp": -28.68060614371613, "outcomes": {"hard_stop": 3, "no_fill_expired": 10, "no_fill_stop": 15, "transition_colour_exit": 35}, "requests": 63, "trade_pf": 0.6842673733963397, "trade_win_rate": 0.18421052631578946, "unknown": 0}, "control": {"executed_closed": 65, "known": 108, "known_no_fill": 43, "mean_known_request_net_bp": -10.74890873554477, "mean_request_gross_bp": 1.2881283014922689, "mean_request_net_bp": -10.74890873554477, "mean_trade_net_bp": -17.85972528367439, "median_trade_net_bp": -31.41263588412267, "outcomes": {"hard_stop": 8, "no_fill_expired": 19, "no_fill_stop": 24, "transition_colour_exit": 57}, "requests": 108, "trade_pf": 0.473043974030227, "trade_win_rate": 0.15384615384615385, "unknown": 0}}, "immediate": {"case": {"executed_closed": 63, "known": 63, "known_no_fill": 0, "mean_known_request_net_bp": -12.809320351906658, "mean_request_gross_bp": 7.190679648093347, "mean_request_net_bp": -12.809320351906658, "mean_trade_net_bp": -12.809320351906658, "median_trade_net_bp": -29.938654511806313, "outcomes": {"hard_stop": 20, "transition_colour_exit": 43}, "requests": 63, "trade_pf": 0.5445556933487665, "trade_win_rate": 0.15873015873015872, "unknown": 0}, "control": {"executed_closed": 108, "known": 108, "known_no_fill": 0, "mean_known_request_net_bp": -22.18002445839848, "mean_request_gross_bp": -2.180024458398476, "mean_request_net_bp": -22.18002445839848, "mean_trade_net_bp": -22.18002445839848, "median_trade_net_bp": -28.50102191678692, "outcomes": {"hard_stop": 40, "transition_colour_exit": 68}, "requests": 108, "trade_pf": 0.33597923207768227, "trade_win_rate": 0.18518518518518517, "unknown": 0}}}

# %% [markdown]
# ## Takeaways
#
# Passing saved accounting does not establish profitability, raw-clock correctness or statistical independence.
